# %% [markdown]
# # dependencies

# %%
from google import genai
import re

from dotenv import load_dotenv
load_dotenv()

import logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)
logger = logging.getLogger(__name__)

try:
    gemini_client = genai.Client()
    logger.info("Gemini client created successfully.")
except Exception as e:
    logger.error("Failed to create Gemini client: %s", e)
    raise
# Out:
# 2025-08-08 17:12:01 - __main__ - INFO - Gemini client created successfully.

# %% [markdown]
# # global config

# %%
EMBEDDING_MODEL = "gemini-embedding-001"

# %% [markdown]
# # core functions

# %%
def chunk_by_structure(document):
    pattern = r"\n## "

    return re.split(pattern, document)

def generate_embeddings(text, model=EMBEDDING_MODEL):
    try:
        response = gemini_client.models.embed_content(
            model=model,
            contents=text
        )
        embeddings = response.embeddings
        logger.info("Embeddings generated successfully.")
        
        return embeddings
    except Exception as e:
        logger.error("Failed to generate embeddings: %s", e)
        raise

# %% [markdown]
# # main function

# %%
def main(doc_file):
    try:
        with open(doc_file, 'r') as file:
            document = file.read()
        
        logger.info("Document read successfully.")
        
        chunks = chunk_by_structure(document)
        logger.info(f"Document split into {len(chunks)} chunks.")

        embeddings = []
        for chunk in chunks:
            chunk_embeddings = generate_embeddings(chunk)
            embeddings.append(chunk_embeddings)
        
        logger.info("All embeddings generated successfully.")
        
        return embeddings
    except Exception as e:
        logger.error("An error occurred in main function: %s", e)
        raise

# %%
main("./assets/report.md")
# Out:
# 2025-08-08 17:12:01 - __main__ - INFO - Document read successfully.
# 2025-08-08 17:12:01 - __main__ - INFO - Document split into 15 chunks.
# 2025-08-08 17:12:01 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:01 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:03 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:03 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:04 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:04 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:05 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:05 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:06 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:06 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:07 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:07 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:07 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:07 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:09 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:09 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:09 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:09 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:10 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:10 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:11 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:11 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:12 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:12 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:13 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:13 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:14 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:14 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:15 - httpx - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# 2025-08-08 17:12:15 - __main__ - INFO - Embeddings generated successfully.
# 2025-08-08 17:12:15 - __main__ - INFO - All embeddings generated successfully.
# [[ContentEmbedding(
#     values=[
#       0.009310254,
#       -0.014552261,
#       -0.0075410446,
#       -0.056133088,
#       0.011788808,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.0036549964,
#       -0.0055337953,
#       0.0059174136,
#       -0.031344205,
#       0.006447381,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.023292294,
#       -0.0028651813,
#       0.008429838,
#       -0.031267766,
#       -0.0006679747,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.014450376,
#       0.009730031,
#       -0.00010011065,
#       -0.039459046,
#       0.012765585,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.0028671417,
#       -0.010705836,
#       -0.018952785,
#       -0.044698812,
#       -0.0031852461,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       -0.0035334064,
#       -0.013167111,
#       -0.009030964,
#       -0.06412988,
#       -0.026197933,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.024057874,
#       -0.002290918,
#       -0.019848296,
#       -0.050952442,
#       -0.0044304603,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.005718384,
#       0.0072194636,
#       -0.003826625,
#       -0.069453545,
#       0.0032773283,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.011544833,
#       0.009315445,
#       -0.008451782,
#       -0.043546557,
#       -0.007866897,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.014109577,
#       0.005748941,
#       0.015262414,
#       -0.06028261,
#       -0.00094965415,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.020680204,
#       0.006693775,
#       0.0019476056,
#       -0.080800444,
#       -0.00360934,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.035713393,
#       -0.01439482,
#       -0.003099252,
#       -0.051936,
#       0.005242627,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.00545026,
#       -0.0024899975,
#       -0.013702561,
#       -0.07760174,
#       -0.014486157,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.012397785,
#       0.018144578,
#       0.002437278,
#       -0.05629292,
#       -0.00066881673,
#       <... 3067 more items ...>,
#     ]
#   )],
#  [ContentEmbedding(
#     values=[
#       0.019028816,
#       -0.014503829,
#       -0.006935013,
#       -0.03949025,
#       0.013384611,
#       <... 3067 more items ...>,
#     ]
#   )]]
